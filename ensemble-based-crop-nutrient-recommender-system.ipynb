# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Ensemble-Based Crop Nutrient Recommender System</i></b>
#     </h1>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#   <title></title>
#   <style>
#     body {
#       font-family: 'Segoe UI', sans-serif;
#       background-color:rgb(167, 233, 213);
#       color: #222;
#       margin: 0;
#       padding: 0;
#       text-align: left;
#     }
#
#     h1 {
#       font-size: 2.5em;
#       margin-top: 80px;
#       padding: 20px;
#       background-color:rgb(229, 212, 212);
#       border: 1px solid #ddd;
#       border-radius: 8px;
#       display: inline-block;
#       color:rgb(49, 108, 167);
#     }
#
#     h1 span {
#       display: block;
#       font-size: 1em;
#       color: #555;
#       margin-top: 8px;
#     }
#
#     .author-container {
#       display: flex;
#       justify-content: center;
#       align-items: center;
#       flex-wrap: wrap;
#       gap: 20px;
#       margin: 30px auto;
#       padding: 20px;
#       max-width: 700px;
#       background-color: #fff;
#       border: 1px solid #ddd;
#       border-radius: 8px;
#     }
#
#     .author-container a {
#       text-decoration: none;
#     }
#
#     .author-container img {
#       border-radius: 6px;
#       padding: 6px;
#       background-color:rgb(234, 234, 234);
#     }
#
#     .author-container a span {
#       display: block;
#       margin-top: 6px;
#       font-size: 0.95em;
#       color: #333;
#     }
#   </style>
# </head>
# <body>
#
# <h1 style="
#   font-family: 'Segoe UI', sans-serif;
#   font-weight: bold;
#   font-style: italic;
#   color:rgb(49, 108, 167);
#   -webkit-font-smoothing: antialiased;
#   text-shadow: 0 1px 1px rgba(218, 55, 55, 0.94);
# ">
#   👨‍🏫 Author: Muhammad Mohsin Farooq
# </h1>
#
#
#   <div class="author-container">
#     <a href="https://github.com/MOHSIN184" target="_blank">
#       <img src="https://img.shields.io/badge/GitHub-Profile-181717?style=for-the-badge&logo=github" alt="GitHub">
#     </a>
#     <a href="https://www.kaggle.com/mmohsinfarooqhussain" target="_blank">
#       <img src="https://img.shields.io/badge/Kaggle-Profile-20BEFF?style=for-the-badge&logo=kaggle" alt="Kaggle">
#     </a>
#     <a href="http://www.linkedin.com/in/m-mohsin-farooq-hussain-962a9a323" target="_blank">
#       <img src="https://img.shields.io/badge/LinkedIn-Profile-0077B5?style=for-the-badge&logo=linkedin" alt="LinkedIn">
#     </a>
#   </div>
#
# </body>
# </html>

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   📂 Dataset Overview
# </h3>
#
# This project uses the **Fertilizer Prediction** dataset ([Kaggle Playground Series – S5E6, 2025](https://www.kaggle.com/competitions/playground-series-s5e6/overview)) to recommend optimal fertilizers based on climate, soil, and crop features. Main feature include temperature, humidity, moisture, soil type, crop type, and soil nutrients (N, P, K). The target is the recommended fertilizer name.
#
# ### Provided files are
#
# * `train.csv` (750,000 samples): Contains features and the target fertilizer label.
# * `test.csv` (250,000 samples): Requires predicting up to **three** fertilizer types per row.
# * `Fertilizer Prediction.csv` (100,000 samples): The original dataset used to generate the synthetic competition data (sources: [IEEE DataPort](https://ieee-dataport.org/documents/soil-fertility-data-fertilizer-recommendation), [Kaggle Dataset](https://www.kaggle.com/datasets/irakozekelly/fertilizer-prediction/data)).
#
# > **Why use the Fertilizer Prediction dataset?**
# Think of `train.csv` as a patient's medical test results (vitals, lab tests, etc.), and `Fertilizer Prediction.csv` as the doctor's prescription based on those results. Without the prescription (fertilizer label), you can't train a supervised model to recommend fertilizers—even if you know all the symptoms (features).
#
# **🔍 When is the original dataset necessary?**
# - Your main dataset lacks the target label (fertilizer name/type).
# - You want to train a supervised ML model to recommend fertilizers from environmental and crop conditions.
# - You aim to augment or join datasets to boost model accuracy by increasing data diversity or quantity.
#
#
# Our main objective is to select the best fertilizer for different weather, soil conditions and crops. per sample, using EDA, feature engineering, and multi-label ranking, evaluated by Log Loss and MAP@3 metrics.

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Import Libraries</i></b>
#     </h1>
# </div>

# %%
# Core data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap, ListedColormap
import colorcet as cc  # Advanced color gradients

# Jupyter display utilities
from IPython.display import display, Markdown, HTML

# Statistical functions
from scipy.stats import skew

# Plotly for interactive plots
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.colors as pc

# Machine learning and preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import log_loss, accuracy_score
from sklearn.model_selection import train_test_split
import xgboost as xgb
import lightgbm as lgb
import catboost as cb

# Suppress warnings for cleaner output
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Load Datasets and Preview the Data</i></b>
#     </h1>
# </div>

# %%
train_data = pd.read_csv('/kaggle/input/playground-series-s5e6/train.csv')
test_data = pd.read_csv('/kaggle/input/playground-series-s5e6/test.csv')
sample_data = pd.read_csv('/kaggle/input/playground-series-s5e6/sample_submission.csv')
original_data = pd.read_csv('/kaggle/input/fertilizer-prediction/Fertilizer Prediction.csv')

# Stylish section headers
display(Markdown("<h2 style='color:#4facfe;'>📦 <b>Dataset Shapes</b></h2>"))
print(f"Train Data Shape: {train_data.shape}")
print(f"Original Data Shape: {original_data.shape}")
print(f"Test Data Shape: {test_data.shape}")

display(Markdown("<h2 style='color:#43e97b;'>🔍 <b>Data Previews</b></h2>"))
display(Markdown("**Train Data (last 5 rows):**"))
display(train_data.tail())

display(Markdown("**Original Data (first 5 rows):**"))
display(original_data.head())

display(Markdown("**Test Data (first 5 rows):**"))
display(test_data.head())

display(Markdown("<h2 style='color:#38f9d7;'>📝 <b>DataFrame Info</b></h2>"))
print("Train Data Info:")
train_data.info()
print('----------------------------------------------------')
print("Original Data Info:")
original_data.info()
print('----------------------------------------------------')
print("Test Data Info:")
test_data.info()
# Out:
# <h2 style='color:#4facfe;'>📦 <b>Dataset Shapes</b></h2>
# Train Data Shape: (750000, 10)
# Original Data Shape: (100000, 9)
# Test Data Shape: (250000, 9)
# <h2 style='color:#43e97b;'>🔍 <b>Data Previews</b></h2>
# **Train Data (last 5 rows):**
#             id  Temparature  Humidity  Moisture Soil Type    Crop Type  \
# 749995  749995           25        69        30    Clayey        Maize
# 749996  749996           37        64        58     Loamy    Sugarcane
# 749997  749997           35        68        59     Sandy  Ground Nuts
# 749998  749998           31        68        29       Red       Cotton
# 749999  749999           33        55        29     Loamy       Cotton
#
#         Nitrogen  Potassium  Phosphorous Fertilizer Name
# 749995         8         16            6           28-28
# 749996        38          8           20        17-17-17
# 749997         6         11           29        10-26-26
# 749998         9         11           12           20-20
# ...

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   What Our Data is Telling Us: An Initial Look
# </h3>
#
#
#
# - **Training data**: 750,000 samples, 10 columns (with `id` and target `Fertilizer Name`).
# - **Original data/Fertilizer prediction**: 100,000 samples, 9 columns (no `id`).
# - **Test data**: 250,000 samples, 9 columns (no target, with `id`).
# - **Features**: Numerical (Temperature, Humidity, Moisture, Nitrogen, Potassium, Phosphorous) and categorical (Soil Type, Crop Type).
# - **Target**: Categorical fertilizer name.
# - **Data quality**: No missing values; types are appropriate (integers for numerics, strings for categoricals).

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Quick Dataset Summary with `skimpy`</i></b>
#     </h1>
# </div>
#
# A fast, visual overview of our main dataframes using the `skimpy` profiling library:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Feature Engineering and Visualization</i></b>
#     </h1>
# </div>

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Define the columns to plot (numerical features)
plot_cols = ['Temparature', 'Humidity', 'Moisture', 'Nitrogen', 'Potassium', 'Phosphorous']

# 3️⃣ Feature Impact by Fertilizer Type (Seaborn version)
for col in plot_cols:
    plt.figure(figsize=(10, 5))
    sns.boxplot(data=original_data, x='Fertilizer Name', y=col, palette='Set2')
    plt.title(f'Boxplot of {col} by Fertilizer Name', fontsize=16, fontweight='bold')
    plt.xlabel('Fertilizer Name')
    plt.ylabel(col)
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(10, 5))
    sns.violinplot(data=original_data, x='Fertilizer Name', y=col, palette='Set2', inner='box')
    plt.title(f'Violin Plot of {col} by Fertilizer Name', fontsize=16, fontweight='bold')
    plt.xlabel('Fertilizer Name')
    plt.ylabel(col)
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   Key Observations
# </h3>
#
#
# **Feature Distribution Consistency**
#
# - The **train**, **original**, and **test** datasets exhibit highly consistent distributions for all numerical features, confirming that the synthetic training data effectively replicates the original data’s statistical properties, and the test set aligns well for fair evaluation.
# - For instance, the mean temperature remains steady at approximately 31.5°C across all datasets, with a comparable range (25°C to 38°C).
# - Humidity, moisture, and soil nutrient levels (Nitrogen, Potassium, Phosphorous) also display similar means and variability, indicating minimal domain shift and supporting robust model training and testing.
#
# **Temperature**
#
# - Ranges from 25°C to 38°C, with a mean near 31.5°C and a standard deviation of about 4.0.
# - The interquartile range (IQR) spans 28°C (25th percentile) to 35°C (75th percentile), reflecting moderate environmental variability.
#
# **Humidity**
#
# - Values range from 50% to 72%, with a mean around 61% and a standard deviation of roughly 6.6.
# - The IQR (55% to 67%) suggests moderate atmospheric moisture variation, relevant for fertilizer uptake.
#
# **Soil Moisture**
#
# - Spans from 25 to 65, averaging around 45, with a standard deviation close to 11.8.
# - This broad range captures diverse soil water content, a key factor for nutrient absorption.
#
# **Soil Nutrients (Nitrogen, Potassium, Phosphorous)**
#
# - **Nitrogen:** 4 to 42 units, mean ≈ 23, std ≈ 11.2
# - **Potassium:** 0 to 19 units, mean ≈ 9.5, std ≈ 5.7
# - **Phosphorous:** 0 to 42 units, mean ≈ 21, std ≈ 12.3
#
# These nutrient distributions highlight substantial variability, underscoring the importance of personalized fertilizer recommendations tailored to specific soil conditions.

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Ensures the Unique Values of all Features</i></b>
#     </h1>
# </div>

# %%
def print_unique_values(df, categorical_columns, dataset_name="Dataset"):
    print("\n" + "=" * 50)
    print(f"Unique values in {dataset_name} categorical features")
    print("=" * 50)
    for col in categorical_columns:
        unique_vals = sorted(df[col].unique())
        value_counts = df[col].value_counts()
        top_value = value_counts.index[0]
        top_freq = value_counts.iloc[0]
        print(f"{col} - Number of unique values: {len(unique_vals)}")
        print(f"Unique values: {unique_vals}")
        print(f"Top value: '{top_value}' (Frequency: {top_freq})\n")

train_cat_cols = ['Soil Type', 'Crop Type', 'Fertilizer Name']
original_cat_cols = ['Soil Type', 'Crop Type', 'Fertilizer Name']
test_cat_cols = ['Soil Type', 'Crop Type']

print_unique_values(train_data, train_cat_cols, "Train Data")
print_unique_values(original_data, original_cat_cols, "Original Data")
print_unique_values(test_data, test_cat_cols, "Test Data")
# Out:
# ...
# Unique values in Train Data categorical features
# ...
# Soil Type - Number of unique values: 5
# Unique values: ['Black', 'Clayey', 'Loamy', 'Red', 'Sandy']
# Top value: 'Sandy' (Frequency: 156710)
#
# Crop Type - Number of unique values: 11
# Unique values: ['Barley', 'Cotton', 'Ground Nuts', 'Maize', 'Millets', 'Oil seeds', 'Paddy', 'Pulses', 'Sugarcane', 'Tobacco', 'Wheat']
# Top value: 'Paddy' (Frequency: 85754)
#
# Fertilizer Name - Number of unique values: 7
# Unique values: ['10-26-26', '14-35-14', '17-17-17', '20-20', '28-28', 'DAP', 'Urea']
# Top value: '14-35-14' (Frequency: 114436)
#
#
# ...
# Unique values in Original Data categorical features
# ...
# Soil Type - Number of unique values: 5
# Unique values: ['Black', 'Clayey', 'Loamy', 'Red', 'Sandy']
# Top value: 'Black' (Frequency: 20100)
#
# Crop Type - Number of unique values: 11
# Unique values: ['Barley', 'Cotton', 'Ground Nuts', 'Maize', 'Millets', 'Oil seeds', 'Paddy', 'Pulses', 'Sugarcane', 'Tobacco', 'Wheat']
# ...

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   Insights into Categorical Features
# </h3>
#
#
#   The summary tables reveal that **"Soil Type"** and **"Crop Type"** share the same unique categories across the train, test, and original datasets, ensuring consistency in feature space. However, the frequency distribution of these categories varies:
#
#   - In the **original data**, "Black" soil and "Sugarcane" crop are most common.
#   - In the **train** and **test** sets, "Sandy" soil and "Paddy" crop dominate.
#
#   This indicates a distribution shift between the original and synthetic datasets, which may impact model generalization. Additionally, the **"Fertilizer Name"** column is present only in the train and original datasets, confirming its role as the target variable for prediction. The absence of this column in the test set highlights the supervised learning setup, where the model must infer fertilizer recommendations for unseen samples.

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Data Quality Checks</i></b>
#     </h1>
# </div>

# %%
import pandas as pd
import plotly.graph_objects as go

def data_quality_report(df_dict):
    summary_data = []

    for name, df in df_dict.items():
        missing = df.isnull().sum().sum()
        dups = df.duplicated().sum()
        total = len(df)

        summary_data.append({
            "Dataset": name,
            "Total Rows": f"{total:,}",
            "Missing Values": f"{missing:,}",
            "Duplicates": f"{dups:,}",
            "Duplicate %": f"{(dups / total):.2%}" if total > 0 else "0.00%"
        })

    summary_df = pd.DataFrame(summary_data)

    fig = go.Figure(data=[go.Table(
        header=dict(
            values=list(summary_df.columns),
            fill_color='gray',
            font=dict(color='white', size=14),
            align='center'
        ),
        cells=dict(
            values=[summary_df[col] for col in summary_df.columns],
            fill_color='lightgray',
            align='center',
            font=dict(size=13)
        )
    )])

    fig.update_layout(
        title="Data Quality Report Summary",
        margin=dict(l=20, r=20, t=40, b=20),
        height=400
    )

    fig.show()

    return summary_df

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   Data Quality Insights: Missing Values and Duplicates
# </h3>
#
#
# - All three datasets—training (750,000 rows), test (250,000 rows), and original (100,000 rows)—are completely free of missing values and duplicate records.
# - This ensures high data integrity and eliminates the need for imputation or duplicate removal during preprocessing.
# - The absence of missing or repeated entries means every sample is unique and complete, supporting reliable model training and evaluation. Such clean data reduces preprocessing complexity and helps prevent bias or overfitting due to repeated samples. Overall, the datasets’ quality provides a strong foundation for robust and trustworthy fertilizer recommendation modeling.

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Data Preprocessing</i></b>
#     </h1>
# </div>

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   🔗 Combine Datasets
# </h3>

# %%
# Drop 'id' column from train_data to align columns
train_data_aligned = train_data.drop(columns=['id'])

# Concatenate train_data_aligned and original_data
combined_data = pd.concat([train_data_aligned, original_data], ignore_index=True)

print(f"Combined dataset shape: {combined_data.shape}")
# Out:
# Combined dataset shape: (850000, 9)

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   Merging Synthetic and Original Datasets
# </h3>
#
#
# - To maximize available information, the synthetic **training data** (750,000 samples) and the **original dataset** (100,000 samples) were merged after dropping the `id` column from the training data to align features.
# - This produced a unified dataset of **850,000 samples** with 9 features, significantly increasing data volume for model training.
# - Combining both datasets leverages the diversity and scale of synthetic data with the authenticity of the original data, supporting more robust model learning.
# - This comprehensive dataset forms the foundation for subsequent preprocessing, feature engineering, and model development, enhancing the reliability and generalizability of fertilizer recommendations.

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Exploratory Data Analysis (EDA)</i></b>
#     </h1>
# </div>

# %%
# Sample data (replace with your actual DataFrame)
fertilizers = ['Urea', 'DAP', 'Potash', 'NPK', 'Compost']
np.random.seed(42)
train_data = pd.DataFrame({
    'Fertilizer Name': np.random.choice(fertilizers, 100),
})
original_data = train_data.copy()

# 🌈 Color-rich, crystal-clear dashboard function
def create_fertilizer_distribution(data, title):
    counts = data['Fertilizer Name'].value_counts().reset_index()
    counts.columns = ['Fertilizer', 'Count']
    
    turbo_colors = pc.sequential.Turbo[:len(counts)]
    bold_colors = pc.qualitative.Bold[:len(counts)+1]  # +1 for root node

    fig = make_subplots(
        rows=1, cols=2,
        subplot_titles=(f"{title} - Count", f"{title} - Sunburst"),
        specs=[[{"type": "bar"}, {"type": "domain"}]]
    )

    # 📊 Bar Chart (Horizontal)
    fig.add_trace(go.Bar(
        y=counts['Fertilizer'],
        x=counts['Count'],
        orientation='h',
        marker=dict(color=counts['Count'], colorscale='Turbo'),
        text=counts['Count'],
        textposition='outside',
        insidetextfont=dict(color='white'),
        outsidetextfont=dict(color='white'),
        name='Fertilizer Count'
    ), row=1, col=1)

    # 🌞 Sunburst Chart
    fig.add_trace(go.Sunburst(
        labels=["Fertilizers"] + counts['Fertilizer'].tolist(),
        parents=[""] + ["Fertilizers"] * len(counts),
        values=[counts['Count'].sum()] + counts['Count'].tolist(),
        branchvalues='total',
        marker=dict(colors=bold_colors),
        textinfo="label+percent entry",
        insidetextfont=dict(size=14, color='white')
    ), row=1, col=2)

    # 🧭 Layout and styling
    fig.update_layout(
        title={
            'text': f"🌱 Fertilizer Distribution Dashboard – {title}",
            'x': 0.5,
            'xanchor': 'center',
            'font': dict(size=24, color='white', family='Arial Black')
        },
        template='plotly_dark',
        paper_bgcolor='#1e1e1e',
        plot_bgcolor='#1e1e1e',
        font=dict(color='white'),
        height=600,
        margin=dict(l=50, r=50, t=80, b=50)
    )

    return fig

# 🚀 Run & Display
fig_train = create_fertilizer_distribution(train_data, "Train Data")
fig_original = create_fertilizer_distribution(original_data, "Original Data")
fig_train.show()
fig_original.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   Insights into Fertilizer Name Distribution
# </h3>
#
#
# + The dashboards reveal that the `Train Data` has an identical fertilizer distribution to the `Original Data`. Both datasets show the exact same counts and percentage splits for each fertilizer type.
#
# + `NPK` is the most prevalent fertilizer, constituting 26% of the data, while `Potash` is the least common at 16%. The other fertilizers (DAP, Compost, Urea) fall in between.
#  + This perfect replication indicates that the training set is not a random sample but rather a direct copy of the original data with respect to the target fertilizer variable, preserving its slightly imbalanced distribution.

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: centre;
#   margin: 20px 0;
# ">
#   Advanced EDA Recommendation
# </h3>
#
#
# For advanced exploratory data analysis (EDA) and feature engineering, consider using the `ydata_profiling` library (formerly `pandas_profiling`). It provides automated, interactive reports with detailed statistics, visualizations, and insights for your DataFrame.
#
# **Example usage:**
#
# `import ydata_profiling`
#
# `profile = ydata_profiling.ProfileReport(original_data)`
#
# `profile.to_file("ydata_profiling_report.html")`
#
# Alternatively, you can directly explore the interactive profiling results here:
# [View YData Profiling Report](https://automatic-eda-of-optimal-fertilizer.netlify.app/)

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   🔗 Feature Encoding
# </h3>

# %%
# ⚙️ Setup
target_variable = 'Fertilizer Name'
categorical_features = ['Soil Type', 'Crop Type']
label_encoders = {}

# 🎯 Encode categorical features
for col in categorical_features:
    le = LabelEncoder()
    combined_data[col + '_Encoded'] = le.fit_transform(combined_data[col])
    label_encoders[col] = le
    
    # Encode test set with fallback
    test_data[col + '_Encoded'] = test_data[col].map(lambda x: le.transform([x])[0] if x in le.classes_ else -1)

# 🎯 Encode target variable
target_le = LabelEncoder()
combined_data[target_variable + '_Encoded'] = target_le.fit_transform(combined_data[target_variable])

# 🧹 Drop original categorical columns
combined_data.drop(columns=categorical_features, inplace=True)
test_data.drop(columns=categorical_features, inplace=True)

# 🧹 Drop original target column
combined_data.drop(columns=[target_variable], inplace=True)

# Print the encoded DataFrame
print("Encoded Combined DataFrame:")
print(combined_data.head())
# Out:
# Encoded Combined DataFrame:
#    Temparature  Humidity  Moisture  Nitrogen  Potassium  Phosphorous  \
# 0           37        70        36        36          4            5
# 1           27        69        65        30          6           18
# 2           29        63        32        24         12           16
# 3           35        62        54        39         12            4
# 4           35        58        43        37          2           16
#
#    Soil Type_Encoded  Crop Type_Encoded  Fertilizer Name_Encoded
# 0                  1                  8                        4
# 1                  4                  4                        4
# 2                  4                  4                        2
# 3                  4                  0                        0
# 4                  3                  6                        5

# %%
# 🧹 Remove whitespace in column names
combined_data.columns = combined_data.columns.str.replace(' ', '_', regex=True)
test_data.columns = test_data.columns.str.replace(' ', '_', regex=True)

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   Categorical Feature Encoding
# </h3>
#
#
# - **Soil Type** and **Crop Type** were label encoded, converting categorical text into numerical codes for compatibility with machine learning algorithms.
# - Encoding was applied consistently to both the combined training and test datasets, ensuring all categories are mapped identically.
# - The target variable, **Fertilizer Name**, was also label encoded to enable multi-class classification.
# - After encoding, the original categorical columns were dropped to avoid redundancy and prevent data leakage.
#
# **Whitespace Removal in Feature Names**
#
# - Whitespaces in feature names were replaced with underscores in both `combined_data` and `test_data`.
# - This standardization ensures reliable column access and clearly distinguishes feature and target variable names for downstream processing.

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Correlation Analysis of Preprocessed Data</i></b>
#     </h1>
# </div>

# %%
# Select only numerical features for correlation
numerical_features = combined_data.select_dtypes(include=['int64', 'int32']).columns.tolist()

corr_matrix = combined_data[numerical_features].corr().round(2)

plt.figure(figsize=(14, 10))

# Use a different colorcet colormap, e.g., cc.m_rainbow or cc.m_bmy for a new look
cmap = cc.m_rainbow  # Try cc.m_bmy, cc.m_coolwarm, etc.

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap=cmap,
    fmt='.2f',
    linewidths=0.5,
    cbar_kws={'shrink': 0.8, 'label': 'Correlation'},
    annot_kws={"size": 11, "weight": "bold", "color": "#222"}
)

plt.title('Correlation Heatmap of Numerical Features', fontsize=18, fontweight='bold', color='#1b1b1b', pad=22)
plt.xticks(rotation=45, ha='right', fontsize=12, color='#1b1b1b')
plt.yticks(rotation=0, fontsize=12, color='#1b1b1b')
plt.gca().set_facecolor('#f7fafd')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   Correlation Analysis of Preprocessed Data
# </h3>
#
#
# - A correlation heatmap of numerical features, including encoded categorical variables and the target, revealed very weak correlations among features and between `features` and the `target`.
# - This indicates that features provide mostly independent information, suggesting the need for models capable of capturing complex, possibly `non-linear relationships`.

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Separating Features and Target</i></b>
#     </h1>
# </div>

# %%
# Select features and target
feature_columns = [
    'Temparature', 'Humidity', 'Moisture', 'Nitrogen', 'Phosphorous', 'Potassium',
    'Soil_Type_Encoded', 'Crop_Type_Encoded'
]
target_column = 'Fertilizer_Name_Encoded'

# Set Training and Test Dataset (no scaling)
X = combined_data[feature_columns]
y = combined_data[target_column]
test_X = test_data[feature_columns]

# %% [markdown]
# <h3 style="
#   font-weight: 600;
#   font-style: italic;
#   font-size: 28px;
#   color: #0575E6;
#   text-align: left;
#   margin: 20px 0;
# ">
#   Insights into Selected Features
# </h3>
#
#
# - The input features selected for model training include environmental variables (`Temparature`, `Humidity`, `Moisture`), soil nutrients (`Nitrogen`, `Phosphorous`, `Potassium`), and encoded categorical variables (`Soil_Type_Encoded`, `Crop_Type_Encoded`).
# - The target variable is the encoded fertilizer class (`Fertilizer_Name_Encoded`).

# %% [markdown]
# <div style="border-radius: 10px; border: 1px solid #8B4513; padding: 10px; background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc); text-align: center; box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);">
#     <h1 style="color: #FFFFFF; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7); font-weight: bold; font-style: italic; margin-bottom: 5px; font-size: 28px; font-family: 'Roboto', sans-serif; letter-spacing: 1px;">
#         <b><i>Evaluation Metric: Mean Average Precision at 3 (MAP@3)</i></b>
#     </h1>
# </div>
#
# **MAP@3** is the competition’s main evaluation metric. It measures how often the correct fertilizer appears in your model’s top 3 predictions, and rewards higher ranks.
#
# ---
#
# ### What is MAP@3?
#
# - **MAP@3** (Mean Average Precision at 3) evaluates both the presence and the rank of the correct fertilizer in your top 3 predictions.
# - The earlier the correct fertilizer appears, the higher the score.
#
# ---
#
# ### How is MAP@3 Calculated?
#
# - For each test sample, your model predicts up to **three fertilizer names** (ordered by confidence).
# - If the correct fertilizer is:
#   - **1st**: Score = **1.0**
#   - **2nd**: Score = **0.5**
#   - **3rd**: Score = **0.333...**
#   - **Not in top 3**: Score = **0.0**
# - **MAP@3** is the average of these scores across all test samples.
#
# ---
#
# ### Formula
#
# $$
# \text{MAP@3} = \frac{1}{U} \sum_{u=1}^{U} \sum_{k=1}^{\min(n, 3)} P(k) \times \text{rel}(k)
# $$
#
# - $U$: Number of test samples
# - $P(k)$: Precision at rank $k$
# - $\text{rel}(k)$: 1 if prediction at $k$ is correct, else 0
#
# ---
#
# ### Example
#
# | Predictions          | AP@3 Score |
# | -------------------- | ---------- |
# | `Urea 14-35-14 DAP`  | 1.0        |
# | `14-35-14 Urea DAP`  | 0.5        |
# | `14-35-14 DAP Urea`  | 0.333      |
# | `14-35-14 DAP 20-20` | 0.0        |
#
# ---
#
# ### Why MAP@3?
#
# - Encourages models to rank the correct fertilizer as high as possible.
# - Useful for recommendation systems where multiple options are suggested.
# - In agriculture, providing the correct fertilizer within the top 3 supports better decision-making.
#
# **Reference:** [Kaggle Evaluation Page](https://www.kaggle.com/competitions/playground-series-s5e6/overview/evaluation)

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Model Evaluation</i></b>
#     </h1>
# </div>

# %%
# import numpy as np
# import pandas as pd
# from sklearn.pipeline import Pipeline
# from sklearn.impute import SimpleImputer
# from sklearn.model_selection import train_test_split, StratifiedKFold
# from sklearn.metrics import log_loss
# from sklearn.base import BaseEstimator, ClassifierMixin
# import xgboost as xgb

# # Split your data
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.2, stratify=y, random_state=42
# )

# class_labels = np.unique(y_train)

# # MAP@3 metric
# def mapk(actual, predicted, k=3):
#     def apk(a, p, k):
#         if len(p) > k:
#             p = p[:k]
#         score = 0.0
#         for i, pred in enumerate(p):
#             if pred == a and pred not in p[:i]:
#                 score += 1.0 / (i + 1.0)
#                 break
#         return score
#     return np.mean([apk(a, p, k) for a, p in zip(actual, predicted)])

# # Optional: Sklearn-compatible XGBoost (not used but kept for flexibility)
# class SklearnCompatibleXGBClassifier(BaseEstimator, ClassifierMixin):
#     def __init__(self, **kwargs):
#         self.model = xgb.XGBClassifier(**kwargs)
#     def fit(self, X, y):
#         self.model.fit(X, y)
#         return self
#     def predict(self, X):
#         return self.model.predict(X)
#     def predict_proba(self, X):
#         return self.model.predict_proba(X)

# # Define models with GPU usage and limited complexity
# models = [
#     ('XGBoost', xgb.XGBClassifier(
#         tree_method='gpu_hist',
#         predictor='gpu_predictor',
#         n_estimators=100,
#         max_depth=6,
#         use_label_encoder=False,
#         eval_metric='mlogloss',
#         verbosity=0,
#         random_state=42
#     ))
# ]

# cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# for name, model in models:
#     print(f"\n🔍 Evaluating {name}")
#     pipeline = Pipeline([
#         ('imputer', SimpleImputer(strategy='most_frequent')),
#         ('model', model)
#     ])

#     fold_log_losses = []
#     fold_map3_scores = []

#     for fold_idx, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train), start=1):
#         X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
#         y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

#         pipeline.fit(X_tr, y_tr)

#         y_proba = pipeline.predict_proba(X_val)
#         y_pred_top3 = np.argsort(y_proba, axis=1)[:, -3:][:, ::-1]
#         y_pred_top3_labels = class_labels[y_pred_top3]

#         # Log Loss
#         ll = log_loss(y_val, y_proba, labels=class_labels)
#         fold_log_losses.append(ll)

#         # MAP@3
#         m3 = mapk(y_val, y_pred_top3_labels, k=3)
#         fold_map3_scores.append(m3)

#         print(f"  Fold {fold_idx} - Log Loss: {ll:.4f}, MAP@3: {m3:.4f}")

#     print(f"\n✅ Average Log Loss: {np.mean(fold_log_losses):.4f}")
#     print(f"✅ Average MAP@3: {np.mean(fold_map3_scores):.4f}")

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i> Feature Importance</i></b>
#     </h1>
# </div>

# %%
# # Extract feature importances from the trained model (last fold)
# feature_importance = model.feature_importances_

# importance_df = pd.DataFrame({
#     'Feature': feature_columns,
#     'Importance': feature_importance
# })

# importance_df = importance_df.sort_values(by='Importance', ascending=False)

# print("Feature Importances:")
# print(importance_df)

# plt.figure(figsize=(12, 6))
# import plotly.express as px

# fig = px.bar(
#     importance_df,
#     x='Importance',
#     y='Feature',
#     orientation='h',
#     color='Importance',
#     color_continuous_scale='Viridis',
#     title='Feature Importance (Last Fold XGBoost Model)',
#     height=500
# )
# fig.update_layout(
#     xaxis_title='Importance Score',
#     yaxis_title='Feature',
#     coloraxis_colorbar=dict(title='Importance'),
#     plot_bgcolor='#f7f7f7'
# )
# fig.show()

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 10px;
#     border: 1px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #2193b0, #6dd5ed 40%, #b2fefa 80%, #e0c3fc);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         font-style: italic;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         <b><i>Prepare Final Submission File</i></b>
#     </h1>
# </div>

# %%
# # Fertilizer decoder
# fertilizer_decoder = dict(zip(target_le.transform(target_le.classes_), target_le.classes_))

# # Generate test_preds using the trained pipeline and test_X
# test_preds = pipeline.predict_proba(test_X)

# test_top3_preds = np.argsort(test_preds, axis=1)[:, -3:][:, ::-1]

# submission_labels = []
# for row in test_top3_preds:
#     labels = [fertilizer_decoder[i] for i in row]
#     submission_labels.append(' '.join(labels))

# submission_df = pd.DataFrame({
#     'id': test_data['id'],
#     'Fertilizer Name': submission_labels
# })
# submission_df.to_csv('my_submission.csv', index=False)
# print("\nSubmission file saved!")

# %%
# # Print Submission preview
# print(submission_df.head(10))

# %% [markdown]
# ___
